# %%
'''
    Instructions: 
    
    1. Run all to see what it does.
    2. Conduct your own experiments by varying the model parameters in Cell 3.  
'''

# %%
import pandas as pd
import statsmodels.api as sm
import itertools
import heapq
import json


'''
    Pipeline:
        1. Calculate Beta for Each Stock in a Given List: all_beta -> 
        2. Given a List of Stocks Find Groupings That Satisfy a Beta Sum Condition:  find_ports ->
        3. Given a List of Portfolios ( List of Stock Tickers ) and a Date Range Compute the
            performance for each portfolio: generate_performance_reports  
        4. Plot Performance: 
'''
def individual_beta(ind_data, stand_data, start_date, end_date):
    #change to our data
    ind_stock = pd.read_csv(ind_data, parse_dates=True, index_col='date',sep = ',')
    ind_stock = ind_stock.reindex(index=ind_stock.index[::-1])
    
    sp_500 = pd.read_csv(stand_data, parse_dates=True, index_col='date', sep = ',')
    sp_500 = sp_500.reindex(index=sp_500.index[::-1])
    
    ind_stock = apply_daterange_filter( ind_stock, start_date, end_date )
    sp_500 = apply_daterange_filter( sp_500, start_date, end_date )
    
    # joining the closing prices of the two datasets 
    #use recent 1 yrs data for training
    monthly_prices = pd.concat([ind_stock.iloc[0:216,3], sp_500.iloc[0:216,3]], axis=1)
    monthly_prices.columns = ['ind', 'SP500']


    # check the head of the dataframe
    #print(monthly_prices)

    # calculate monthly returns
    monthly_returns = monthly_prices.pct_change(1)
    clean_monthly_returns = monthly_returns.dropna(axis=0)  # drop first missing row

    # split dependent and independent variable
    X = clean_monthly_returns['SP500']
    y = clean_monthly_returns['ind']
    if(len(X) > 0):
        # Add a constant to the independent value
        X1 = sm.add_constant(X)

        # make regression model 
        model = sm.OLS(y, X1)

        # fit model and print results
        results = model.fit()
        #beta of the individual stock
        return results.params[1]
    else:
        return 0

    
'''
compute beta for all stocks in a given list
'''
def all_beta(s_list, dPath, mPath, start_date, end_date):
    b_list = []
    for stock in s_list:
        stock_path = dPath + str(stock) + '.csv'
        stock_Beta = individual_beta(stock_path, mPath, start_date, end_date)
        if stock_Beta >= -20 and stock_Beta <= 100:
            b_list.append((stock, stock_Beta))
#         else:
#             print(stock, stock_Beta)
    return b_list


'''
generate portfolios
'''
def findPorts(s_list, num, thre):#stock list, size of portfolio, threshold
    port_list = []
    cand_portfolios = set(itertools.combinations(s_list, num))
    for cand_port in cand_portfolios:
        beta_sum = sum(n for _ , n in cand_port)
        if (beta_sum >= thre):
            port_list.append(cand_port)
    return port_list


    
'''
    Return dictionary with structure: 
    
    {
        stock_list, 
        df_of_performance_of_each_stock_in_stock_list,
        portfolio_performance
    }
    
'''
def get_individual_porfolio_performance( stock_list, start_date, end_date ):
    data_directory = './AlphaData/'
    
    master_df = pd.DataFrame()
    
    for ticker in stock_list:
        stock_df = pd.read_csv( data_directory + ticker + ".csv", parse_dates=True, index_col='date', sep = ',')
        stock_df = stock_df.reindex(index=stock_df.index[::-1])
        stock_df = apply_daterange_filter( stock_df['close'], start_date, end_date )
        master_df[ ticker ] = stock_df
    
    master_df[ 'portfolio' ] =  master_df.sum( axis=1 )
    master_df[ 'performance' ] = master_df[ 'portfolio'].pct_change().fillna(0).cumsum()
     
    report = {
        "stock_list": stock_list,
        "data": master_df,
        "performance": master_df[ 'performance' ][-1]
    }
    
    return report

    
    
def apply_daterange_filter( df, start_date, end_date ):
    _filter = ( df.index.get_level_values(0) >= start_date ) & ( df.index.get_level_values(0) <= end_date )
    return df[ _filter ]

class PerformanceReportObject:
    def __init__(self, max_heap_of_performance_reports):
        self.reports = max_heap_of_performance_reports 
    
    def get_top_n_performing_portfolios(self, n):
        n = min ( len(self.reports), n ) 
        top_n_performing_portfolios = [ heapq.heappop( self.reports ) for i in range( n ) ]
        
        for i in range(n):
            heapq.heappush( self.reports, top_n_performing_portfolios[i] )
        
        return [ report[-1] for report in top_n_performing_portfolios ] 
    
    '''
        For each portfolio in the report,
        plot performance vs time
    '''
    def plot_performance(self, n=-1):
        if ( n == -1 ):
            n = len(self.reports)
            
        ax = None
        for i in range(n):
            report = self.reports[i][2]
            if ( ax == None ):
                ax = report["data"]["performance"].plot()
            else:
                report["data"]["performance"].plot( ax=ax )

        return ax
    
    
def generate_performance_reports( portfolios, start_date, end_date ):
    performance_report = []
    for portfolio in portfolios:
        _stock_list = []
        _beta_sum = 0
        for i in range(len(portfolio)):
            _stock_list.append( portfolio[i][0] )
            _beta_sum += portfolio[i][1]

        _report = get_individual_porfolio_performance( _stock_list, start_date, end_date )
        _report["beta_sum"] = _beta_sum

        heapq.heappush( performance_report, ( -1 * _report["performance"], id(_report), _report )  ) # push to list while maintaining max-heap constraint

    return PerformanceReportObject( performance_report )

# %%
'''0: Get Initial Data'''

# This is cell 3

cache = None
with open("cache.json") as cache_file:
    cache = json.load( cache_file )

stock_list = cache["stock_list"]

model_parameters = {
    "data_directory": './AlphaData/',
    "sp500_data_file": './AlphaData/SPY.csv', 
    "test": {
        "start_date": "2018-01-01",
        "end_date":"2018-12-31"
    },
    "train": {
        "start_date": "2010-01-04",
        "end_date":"2017-12-29"
    }
}

universe_size = 100
portfolio_size = 3

# %%
'''1. Calculate Beta for Each Stock in a Given List: '''

beta_list = all_beta( stock_list[:100], 
                     model_parameters["data_directory"], 
                     model_parameters["sp500_data_file"],
                     model_parameters["train"]["start_date"],
                     model_parameters["train"]["end_date"]
                    )
# Out:
# c:\users\tareg\appdata\local\programs\python\python37-32\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
'''2. Given a List of Stocks Find Groupings That Satisfy a Beta Sum Condition:'''
portfolios = findPorts( beta_list, 3, 6 )

portfolios
# Out:
# [(('AIG', 1.5552725710870863),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AAL', 1.8288872208595113),
#   ('AIV', 1.686824423683121),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('AXP', 1.457823201850238),
#   ('BC', 2.5149010081970467)),
#  (('AAL', 1.8288872208595113),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ANF', 1.511619829135043),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467),
#   ('BEN', 1.4598935720602233)),
#  (('AMP', 1.539754144089544),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AIV', 1.686824423683121),
#   ('ASH', 1.8097191414024552),
#   ('BC', 2.5149010081970467)),
#  (('AIV', 1.686824423683121),
#   ('AMD', 1.8390941788220037),
#   ('BC', 2.5149010081970467)),
#  (('AAL', 1.8288872208595113),
#   ('ASH', 1.8097191414024552),
#   ('BC', 2.5149010081970467)),
#  (('ALB', 1.382999627782583),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467),
#   ('CAT', 1.4863641546765025)),
#  (('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467),
#   ('BRK.B', 1.534963634556192)),
#  (('AAL', 1.8288872208595113),
#   ('AFL', 1.7014970995027363),
#   ('BC', 2.5149010081970467)),
#  (('AMD', 1.8390941788220037),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ALK', 1.5594397350929956),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467),
#   ('BHGE', 1.6018170608931868)),
#  (('AFL', 1.7014970995027363),
#   ('ASH', 1.8097191414024552),
#   ('BC', 2.5149010081970467)),
#  (('ARNC', 1.5387348110125663),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AES', 1.5816625566073514),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AFL', 1.7014970995027363),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467),
#   ('BWA', 1.5199627604839512)),
#  (('AFL', 1.7014970995027363),
#   ('AMD', 1.8390941788220037),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467),
#   ('C', 1.4371247173791795)),
#  (('AAL', 1.8288872208595113),
#   ('AMD', 1.8390941788220037),
#   ('BC', 2.5149010081970467)),
#  (('ADSK', 1.5006075948355653),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AMG', 1.5582468530973108),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('ASH', 1.8097191414024552),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AIV', 1.686824423683121),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467)),
#  (('AMD', 1.8390941788220037),
#   ('ASH', 1.8097191414024552),
#   ('BC', 2.5149010081970467)),
#  (('ATI', 2.1038272980883552),
#   ('BAC', 1.5554689616142896),
#   ('BC', 2.5149010081970467)),
#  (('AA', 1.5387505364585359),
#   ('ATI', 2.1038272980883552),
#   ('BC', 2.5149010081970467))]

# %%
'''3. Given a List of Portfolios ( List of Stock Tickers ) and a Date Range Compute the
            performance for each portfolio'''

report_object_test_daterange = generate_performance_reports(portfolios,
                                            model_parameters["test"]["start_date"],
                                            model_parameters["test"]["end_date"]
                                            )

report_object_training_daterange = generate_performance_reports(portfolios,
                                            model_parameters["train"]["start_date"],
                                            model_parameters["train"]["end_date"]
                                            )

# %%
test_performance_graph = report_object_test_daterange.plot_performance()

test_performance_graph.set_xlabel('Percentage')
test_performance_graph.set_xlabel('Date')
test_performance_graph.set_title(
    'Top Performaning {}-Sized Portfolios for the Date Range {} to {}'.format(
        portfolio_size,
        model_parameters["test"]["start_date"],
        model_parameters["test"]["end_date"],
    )
)

test_performance_graph

# %%
training_performance_graph = report_object_training_daterange.plot_performance()

training_performance_graph.set_xlabel('Percentage')
training_performance_graph.set_xlabel('Date')
training_performance_graph.set_title(
    'Top Performaning {}-Sized Portfolios for the Date Range {} to {}'.format(
        portfolio_size,
        model_parameters["train"]["start_date"],
        model_parameters["train"]["end_date"],
    )
)
# Out:
# Text(0.5, 1.0, 'Top Performaning 3-Sized Portfolios for the Date Range 2010-01-04 to 2017-12-29')

# %%
top_5_performing_stocks_test = report_object_test_daterange.get_top_n_performing_portfolios(n=5)

top_5_performing_stocks_test
# Out:
# [{'stock_list': ['ADSK', 'ATI', 'BC'],
#   'data':               ADSK    ATI     BC  portfolio  performance
#   date
#   2018-01-02  107.12  25.62  55.99     188.73     0.000000
#   2018-01-03  109.38  26.11  56.25     191.74     0.015949
#   2018-01-04  112.07  26.64  55.77     194.48     0.030239
#   2018-01-05  110.84  26.67  56.76     194.27     0.029159
#   2018-01-08  111.42  27.26  56.95     195.63     0.036160
#   ...            ...    ...    ...        ...          ...
#   2018-12-24  118.32  21.21  42.61     182.14     0.011446
#   2018-12-26  125.93  22.17  44.94     193.04     0.071290
#   2018-12-27  127.41  22.30  45.86     195.57     0.084396
#   2018-12-28  127.23  21.94  46.15     195.32     0.083118
#   2018-12-31  128.61  21.77  46.45     196.83     0.090849
#
#   [251 rows x 5 columns],
#   'performance': 0.09084892494906949,
#   'beta_sum': 6.119335901120968},
#  {'stock_list': ['AIV', 'AMD', 'BC'],
#   'data':               AIV    AMD     BC  portfolio  performance
#   date
#   2018-01-02  43.45  10.98  55.99     110.42     0.000000
#   2018-01-03  43.51  11.55  56.25     111.31     0.008060
#   2018-01-04  42.82  12.12  55.77     110.71     0.002670
#   2018-01-05  42.56  11.88  56.76     111.20     0.007096
#   2018-01-08  42.89  12.28  56.95     112.12     0.015369
#   ...           ...    ...    ...        ...          ...
#   2018-12-24  42.22  16.65  42.61     101.48    -0.060308
#   2018-12-26  43.43  17.90  44.94     106.27    -0.013106
#   2018-12-27  43.52  17.49  45.86     106.87    -0.007460
#   2018-12-28  43.48  17.82  46.15     107.45    -0.002033
#   2018-12-31  43.88  18.46  46.45     108.79     0.010438
#
#   [251 rows x 5 columns],
#   'performance': 0.010437881372939328,
#   'beta_sum': 6.040819610702171},
#  {'stock_list': ['ATI', 'BC', 'BRK.B'],
#   'data':               ATI     BC   BRK.B  portfolio  performance
#   date
#   2018-01-02  25.62  55.99  197.22     278.83     0.000000
#   2018-01-03  26.11  56.25  199.79     282.15     0.011907
#   2018-01-04  26.64  55.77  200.69     283.10     0.015274
#   2018-01-05  26.67  56.76  201.42     284.85     0.021455
#   2018-01-08  27.26  56.95  202.74     286.95     0.028828
#   ...           ...    ...     ...        ...          ...
#   2018-12-24  21.21  42.61  187.76     251.58    -0.082533
#   2018-12-26  22.17  44.94  197.57     264.68    -0.030462
#   2018-12-27  22.30  45.86  200.12     268.28    -0.016861
#   2018-12-28  21.94  46.15  202.08     270.17    -0.009816
#   2018-12-31  21.77  46.45  204.18     272.40    -0.001562
#
#   [251 rows x 5 columns],
#   'performance': -0.0015618012405926862,
#   'beta_sum': 6.153691940841593},
#  {'stock_list': ['AMD', 'ASH', 'BC'],
#   'data':               AMD    ASH     BC  portfolio  performance
#   date
#   2018-01-02  10.98  73.13  55.99     140.10     0.000000
#   2018-01-03  11.55  73.59  56.25     141.39     0.009208
#   2018-01-04  12.12  73.69  55.77     141.58     0.010552
#   2018-01-05  11.88  74.08  56.76     142.72     0.018603
#   2018-01-08  12.28  73.38  56.95     142.61     0.017833
#   ...           ...    ...    ...        ...          ...
#   2018-12-24  16.65  65.28  42.61     124.54    -0.091229
#   2018-12-26  17.90  68.22  44.94     131.06    -0.038877
#   2018-12-27  17.49  70.68  45.86     134.03    -0.016215
#   2018-12-28  17.82  70.25  46.15     134.22    -0.014798
#   2018-12-31  18.46  70.96  46.45     135.87    -0.002504
#
#   [251 rows x 5 columns],
#   'performance': -0.0025044765096609023,
#   'beta_sum': 6.163714328421506},
#  {'stock_list': ['AMD', 'ATI', 'BC'],
#   'data':               AMD    ATI     BC  portfolio  performance
#   date
#   2018-01-02  10.98  25.62  55.99      92.59     0.000000
#   2018-01-03  11.55  26.11  56.25      93.91     0.014256
#   2018-01-04  12.12  26.64  55.77      94.53     0.020858
#   2018-01-05  11.88  26.67  56.76      95.31     0.029110
#   2018-01-08  12.28  27.26  56.95      96.49     0.041490
#   ...           ...    ...    ...        ...          ...
#   2018-12-24  16.65  21.21  42.61      80.47    -0.099619
#   2018-12-26  17.90  22.17  44.94      85.01    -0.043201
#   2018-12-27  17.49  22.30  45.86      85.65    -0.035672
#   2018-12-28  17.82  21.94  46.15      85.91    -0.032637
#   2018-12-31  18.46  21.77  46.45      86.68    -0.023674
#
#   [251 rows x 5 columns],
#   'performance': -0.0236738467922063,
#   'beta_sum': 6.457822485107405}]

# %%
'''
    The top performing portfolios have the same stock in common 
'''
# Out:
# '\n    The top performing portfolios have the same stock in common \n'
